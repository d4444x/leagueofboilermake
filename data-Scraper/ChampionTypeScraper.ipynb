# %%
from BeautifulSoup import BeautifulSoup
import urllib2
import re

# %%
url= ["http://leagueoflegends.wikia.com/wiki/Category:Interrupt_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Blocker_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Fear_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Pull_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Knockback_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Knockup_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Silence_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Stun_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Taunt_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Suppress_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Slow_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Snare_champion"]

# %%
url= ["http://leagueoflegends.wikia.com/wiki/Category:Assassin_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Carry_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Fighter_champion",
      ""]

# %%
dic = {}
for u in url:
    CCType = re.search(r"y:(.*)", u).group(1)
    page=urllib2.urlopen(u)
    soup = BeautifulSoup(page.read())
    champs = []
    for li in soup('li'):
        for a in li.findAll('a',text = re.compile('/Ability'),attrs={'class': None}):
            name = a.replace('/Ability Details','')
            if name not in champs:
                champs.append(name)
    dic[CCType] = champs

# %%
dic
# Out:
# {'Blocker_champion': [u'Jarvan IV'],
#  'Fear_champion': [u'Hecarim', u'Nocturne', u'Shaco', u'Volibear'],
#  'Interrupt_champion': [u'Darius',
#   u'Draven',
#   u'Garen',
#   u'Gragas',
#   u'Hecarim',
#   u'Irelia',
#   u'Janna',
#   u'Jarvan IV',
#   u'Jax',
#   u'Jayce',
#   u'Kassadin',
#   u'Lee Sin',
#   u'Leona',
#   u'Lulu',
#   u'Malphite',
#   u'Malzahar',
#   u'Morgana',
#   u'Nautilus',
#   u'Nocturne',
#   u'Orianna',
#   u'Pantheon',
#   u'Poppy',
#   u'Rammus',
#   u'Renekton',
#   u'Riven',
#   u'Sejuani',
#   u'Shaco',
#   u'Shen',
#   u'Shyvana',
#   u'Singed',
#   u'Sion',
#   u'Skarner',
#   u'Sona',
#   u'Soraka',
#   u'Taric',
#   u'Tristana',
#   u'Twisted Fate',
#   u'Udyr',
#   u'Urgot',
#   u'Vayne',
#   u'Veigar',
#   u'Volibear',
#   u'Warwick',
#   u'Xin Zhao',
#   u'Zac'],
#  'Knockback_champion': [u'Draven',
#   u'Gragas',
#   u'Hecarim',
#   u'Janna',
#   u'Jayce',
#   u'Lee Sin',
#   u'Poppy',
#   u'Rammus',
#   u'Shyvana',
#   u'Syndra',
# ...

# %%
# Out:
# 'Interrupt_champion'

# %%
champs
# Out:
# [u'Darius',
#  u'Draven',
#  u'Garen',
#  u'Gragas',
#  u'Hecarim',
#  u'Irelia',
#  u'Janna',
#  u'Jarvan IV',
#  u'Jax',
#  u'Jayce',
#  u'Kassadin',
#  u'Lee Sin',
#  u'Leona',
#  u'Lulu',
#  u'Malphite',
#  u'Malzahar',
#  u'Morgana',
#  u'Nautilus',
#  u'Nocturne',
#  u'Orianna',
#  u'Pantheon',
#  u'Poppy',
#  u'Rammus',
#  u'Renekton',
#  u'Riven',
#  u'Sejuani',
#  u'Shaco',
#  u'Shen',
#  u'Shyvana',
#  u'Singed',
#  u'Sion',
#  u'Skarner',
#  u'Sona',
#  u'Soraka',
#  u'Taric',
#  u'Tristana',
#  u'Twisted Fate',
#  u'Udyr',
#  u'Urgot',
#  u'Vayne',
#  u'Veigar',
#  u'Volibear',
#  u'Warwick',
#  u'Xin Zhao',
#  u'Zac']
