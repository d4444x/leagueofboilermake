# %%
from BeautifulSoup import BeautifulSoup
import urllib2
import re

# %%
url= ["http://leagueoflegends.wikia.com/wiki/Category:Interrupt_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Blocker_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Fear_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Pull_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Knockback_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Knockup_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Silence_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Stun_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Taunt_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Suppress_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Slow_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Snare_champion"]

# %%
url= ["http://leagueoflegends.wikia.com/wiki/Category:Blind_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Blink_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Dash_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Execution_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Global_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Haste_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Healer_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Mana_Heal_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Nuke_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Pet_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Scout_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Self_Heal_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Shapeshifter_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Shield_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Stance_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Teleport_champion"]

# %%
url= ["http://leagueoflegends.wikia.com/wiki/Category:Assassin_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Carry_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Fighter_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Jungler_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Mage_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Melee_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Pusher_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Ranged_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Stealth_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Support_champion",
      "http://leagueoflegends.wikia.com/wiki/Category:Tank_champion"]

# %%
dic = {}
for u in url:
    CCType = re.search(r"y:(.*)", u).group(1)
    page=urllib2.urlopen(u)
    soup = BeautifulSoup(page.read())
    champs = []
    for li in soup('li'):
        for a in li.findAll('a',text = re.compile('/Ability'),attrs={'class': None}):
            name = a.replace('/Ability Details','')
            if name not in champs:
                champs.append(name)
        for a in li.findAll('a',text = re.compile('Details/'),attrs={'class': None}):
            name = a.replace('Ability Details/','')
            if name not in champs:
                champs.append(name)
    dic[CCType] = champs

# %%
dic
# Out:
# {'Assassin_champion': [u'Ahri',
#   u'Evelynn',
#   u'Fiora',
#   u'Irelia',
#   u'Kassadin',
#   u'Katarina',
#   u"Kha'Zix",
#   u'LeBlanc',
#   u'Lee Sin',
#   u'Malzahar',
#   u'Nidalee',
#   u'Pantheon',
#   u'Poppy',
#   u'Rengar',
#   u'Riven',
#   u'Shaco',
#   u'Tryndamere',
#   u'Twitch',
#   u'Vayne',
#   u'Vi',
#   u'Xin Zhao',
#   u'Shaco',
#   u'Zed'],
#  'Carry_champion': [],
#  'Fighter_champion': [u'Darius',
#   u'Elise',
#   u'Fiora',
#   u'Gragas',
#   u'Hecarim',
#   u'Irelia',
#   u'Jarvan IV',
#   u'Jayce',
#   u'Lee Sin',
#   u'Malphite',
#   u'Mordekaiser',
#   u'Nunu',
#   u'Pantheon',
#   u'Poppy',
#   u'Rammus',
#   u'Renekton',
#   u'Rengar',
#   u'Riven',
#   u'Rumble',
#   u'Sejuani',
#   u'Shen',
#   u'Shyvana',
#   u'Singed',
#   u'Sion',
#   u'Skarner',
#   u'Taric',
#   u'Thresh',
#   u'Trundle',
#   u'Tryndamere',
#   u'Udyr',
#   u'Vi',
#   u'Volibear',
#   u'Warwick',
#   u'Xin Zhao',
#   u'Zac',
#   u'Gangplank',
#   u'Nautilus',
#   u'Zed'],
# ...

# %%
dic['Support_champion'].append(u'Zyra')

# %%
for li in soup('li'):
    for a in li.findAll('a',text = re.compile('/Ability'),attrs={'class': None}):
        name = a.replace('/Ability Details','')
        if name not in champs:
            champs.append(name)
    for a in li.findAll('a',text = re.compile('Details/'),attrs={'class': None}):
        name = a.replace('Ability Details/','')
        if name not in champs:
            champs.append(name)

# %%
champs
# Out:
# [u'Nautilus',
#  u'Darius',
#  u'Hecarim',
#  u'Jarvan IV',
#  u'Leona',
#  u'Malphite',
#  u'Rammus',
#  u'Renekton',
#  u'Sejuani',
#  u'Shen',
#  u'Shyvana',
#  u'Singed',
#  u'Skarner',
#  u'Trundle',
#  u'Udyr',
#  u'Urgot',
#  u'Volibear',
#  u'Warwick',
#  u'Zac']
